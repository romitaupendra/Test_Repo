# %%
import boto3
from botocore.handlers import disable_signing
resource = boto3.resource('s3')
resource.meta.client.meta.events.register('choose-signer.s3.*', disable_signing)
bucket=resource.Bucket('sevir')

objs=bucket.objects.filter(Prefix='')
print([o.key for o in objs])
# Out:
# ['CATALOG.csv', 'data/', 'data/ir069/2018/SEVIR_IR069_RANDOMEVENTS_2018_0101_0430.h5', 'data/ir069/2018/SEVIR_IR069_RANDOMEVENTS_2018_0501_0831.h5', 'data/ir069/2018/SEVIR_IR069_RANDOMEVENTS_2018_0901_1231.h5', 'data/ir069/2018/SEVIR_IR069_STORMEVENTS_2018_0101_0630.h5', 'data/ir069/2018/SEVIR_IR069_STORMEVENTS_2018_0701_1231.h5', 'data/ir069/2019/SEVIR_IR069_RANDOMEVENTS_2019_0101_0430.h5', 'data/ir069/2019/SEVIR_IR069_RANDOMEVENTS_2019_0501_0831.h5', 'data/ir069/2019/SEVIR_IR069_RANDOMEVENTS_2019_0901_1231.h5', 'data/ir069/2019/SEVIR_IR069_STORMEVENTS_2019_0101_0630.h5', 'data/ir069/2019/SEVIR_IR069_STORMEVENTS_2019_0701_1231.h5', 'data/ir107/2018/SEVIR_IR107_RANDOMEVENTS_2018_0101_0430.h5', 'data/ir107/2018/SEVIR_IR107_RANDOMEVENTS_2018_0501_0831.h5', 'data/ir107/2018/SEVIR_IR107_RANDOMEVENTS_2018_0901_1231.h5', 'data/ir107/2018/SEVIR_IR107_STORMEVENTS_2018_0101_0630.h5', 'data/ir107/2018/SEVIR_IR107_STORMEVENTS_2018_0701_1231.h5', 'data/ir107/2019/SEVIR_IR107_RANDOMEVENTS_2019_01
# ...

# %%
bucket.download_file('CATALOG.csv','/Users/nishanthrk/Documents/CSYE7245/SEVIR/CATALOG.csv')
bucket.download_file('data/vis/2019/SEVIR_VIS_RANDOMEVENTS_2019_0621_0630.h5','/Users/nishanthrk/Documents/CSYE7245/SEVIR/SEVIR_VIS_RANDOMEVENTS_2019_0621_0630.h5')
bucket.download_file('data/vis/2019/SEVIR_VIS_STORMEVENTS_2019_0601_0630.h5','/Users/nishanthrk/Documents/CSYE7245/SEVIR/SEVIR_VIS_STORMEVENTS_2019_0601_0630.h5')
bucket.download_file('data/vil/2019/SEVIR_VIL_RANDOMEVENTS_2019_0501_0831.h5','/Users/nishanthrk/Documents/CSYE7245/SEVIR/SEVIR_VIL_RANDOMEVENTS_2019_0501_0831.h5')
bucket.download_file('data/vil/2019/SEVIR_VIL_STORMEVENTS_2019_0101_0630.h5','/Users/nishanthrk/Documents/CSYE7245/SEVIR/SEVIR_VIL_STORMEVENTS_2019_0101_0630.h5')
bucket.download_file('data/lght/2019/SEVIR_LGHT_ALLEVENTS_2019_0601_0701.h5','/Users/nishanthrk/Documents/CSYE7245/SEVIR/SEVIR_LGHT_ALLEVENTS_2019_0601_0701.h5')
bucket.download_file('data/ir069/2019/SEVIR_IR069_RANDOMEVENTS_2019_0501_0831.h5','/Users/nishanthrk/Documents/CSYE7245/SEVIR/SEVIR_IR069_RANDOMEVENTS_2019_0501_0831.h5')
bucket.download_file('data/ir069/2019/SEVIR_IR069_STORMEVENTS_2019_0101_0630.h5','/Users/nishanthrk/Documents/CSYE7245/SEVIR/SEVIR_IR069_STORMEVENTS_2019_0101_0630.h5')
bucket.download_file('data/ir107/2019/SEVIR_IR107_RANDOMEVENTS_2019_0501_0831.h5','/Users/nishanthrk/Documents/CSYE7245/SEVIR/SEVIR_IR107_RANDOMEVENTS_2019_0501_0831.h5')
bucket.download_file('data/ir107/2019/SEVIR_IR107_STORMEVENTS_2019_0101_0630.h5','/Users/nishanthrk/Documents/CSYE7245/SEVIR/SEVIR_IR107_STORMEVENTS_2019_0101_0630.h5')
# Out:
# "bucket.download_file('data/ir107/2019/SEVIR_IR107_RANDOMEVENTS_2019_0501_0831.h5','/Users/nishanthrk/Documents/CSYE7245/SEVIR/SEVIR_IR107_RANDOMEVENTS_2019_0501_0831.h5')\nbucket.download_file('data/ir107/2019/SEVIR_IR107_STORMEVENTS_2019_0101_0630.h5','/Users/nishanthrk/Documents/CSYE7245/SEVIR/SEVIR_IR107_STORMEVENTS_2019_0101_0630.h5')"
